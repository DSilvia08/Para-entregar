# %% [markdown]
# <a href="https://colab.research.google.com/github/DSilvia08/Para-entregar/blob/main/Generador_congruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Este programa es para la generación de "números aleatorios" con el Método de Congruencia

print("Método de Congruencia")
m=int(input("Ingrese un valor para m: ")) #"ciclo de vida", valor constante
x_n=int(input("Ingrese un número menor que m y mayor que 0: "))#semilla
#valores constantes
a=int(input("Ingrese un valor para a: "))
c=int(input("Ingrese un valor para c: "))

print("{:<8} {:<10} {:<10} {:<8} {:<15}".format("n", "x_n", "ax_n+c", "ax_n+c % m", "x_n/m"))#Encabezado de la tabla

for n in range(0,m):
  P=(a*x_n) + c #Función
  M=P%m #módulo entre producto y m
  N=x_n/m #como los números son mayores a 1 y trabajamos con valores uniformemente distribuimos
  #dividimos la semilla entre un número conveniente, siendo este m
  N=round(N,4) #redondeamos decimales
  d=[[n, x_n, P, M, N]] #datos de la tabala
  print("{:<8} {:<10} {:<10} {:<8} {:<15}".format(n, x_n, P, M, N))
  x_n=M #nueva semilla y se reinicia el método hasta m datos
# Out:
# Método de Congruencia
# Ingrese un valor para m: 100
# Ingrese un número menor que m y mayor que 0: 27
# Ingrese un valor para a: 17
# Ingrese un valor para c: 43
# n        x_n        ax_n+c     ax_n+c % m x_n/m
# 0        27         502        2        0.27
# 1        2          77         77       0.02
# 2        77         1352       52       0.77
# 3        52         927        27       0.52
# 4        27         502        2        0.27
# 5        2          77         77       0.02
# 6        77         1352       52       0.77
# 7        52         927        27       0.52
# 8        27         502        2        0.27
# 9        2          77         77       0.02
# 10       77         1352       52       0.77
# 11       52         927        27       0.52
# 12       27         502        2        0.27
# 13       2          77         77       0.02
# 14       77         1352       52       0.77
# 15       52         927        27       0.52
# ...
