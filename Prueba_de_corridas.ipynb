# %% [markdown]
# <a href="https://colab.research.google.com/github/DSilvia08/Para-entregar/blob/main/Prueba_de_corridas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Del ejercicio 2. Problema 1
#Realice una prueba de corridas con un nivel de aceptación del 95 %
L=[0.048, 0.591, 0.478, 0.166, 0.932, 0.926, 0.007, 0.551, 0.362, 0.533,
   0.368, 0.437, 0.178, 0.411, 0.545, 0.787, 0.594, 0.086, 0.951, 0.772,
   0.298, 0.199, 0.157, 0.401, 0.631]
print("Prueba de Corridas") #Es una prueba de independencia
#Corrida o racha es una sucesión de resuktados de la misma clase

#Paso 1. Determinar una secuencias de unos y ceros
k=len(L)
S=[]
a=1
b=0
while a<k and b<=(k-1):
  u=L[a]-L[b]
  if u<=0:
    S.append(0) #se agrega un 0 si x_i <= x_i-1
    a+=1
    b+=1
  else:
    S.append(1) #1 en caso contrario
    a+=1
    b+=1
#Paso 2. Hallar el número de corridas observadas
c=0
if S[0]==1:
  c+=1
else:
  c+=1
for n in S:
  if S[n+1] != S[n]:
    c+=1
  else:
    c+=0
c+=1 #se suma 1 más porque el ciclo cuenta n-1 rachas
j=["----"] #como el conteo de rachas comienza con el segundo dato,
#en la primera fila le agreagré estas lineas
S=j+S # en la primera fila le agreagré estas lineas

#Tabla
# !pip install prettytable
from prettytable import PrettyTable
myTable = PrettyTable(["n","X_i","numero"])#encabezado de la tabla

for x in range(k):
  myTable.add_row([x,L[x],S[x]])#datos
print(myTable)
print("")
#Hipótesis
print("H_o = Los números de la muestra son independientes")
print("H_a = Los números de la muestra no son independientes")
print("")
#Caclulamos la media, varianza y Z
media=((2*k)-1)/3
varianza=((16*k)-29)/90
from math import sqrt
Z=(c-media)/sqrt(varianza)
#como C_0 ~N(media, distribución estandar) es equivalente a Z_0~N(0,1)
m=float(input("Nivel de aceptación: ")) #nivel de aceptación
from scipy.stats import norm
n_sd=(1-m)/2 #nivel de significancia entre 2
N=1-n_sd #probabilidad acumulada
valor_z=norm.ppf(N)#la funcion norm.ppf sirve para calcular el valor Z
#correspondiente a una probabilidad acumulada
print("Rachas observadas: ", c)
print("media", round(media,4))
print("varianza", round(varianza,4))
print("")
print("Valor z en N(0,1)", round(valor_z,2))
print("Valor de Z_o", round(Z,4))
print("")
if valor_z*(-1)<Z and Z<valor_z:
  print(valor_z*(-1),"<",Z,"<",valor_z)
  print("H_o se acepta")
else:
  print("H_o se rechaza")
# Out:
# Prueba de Corridas
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable) (0.2.13)
# +----+-------+--------+
# | n  |  X_i  | numero |
# +----+-------+--------+
# | 0  | 0.048 |  ----  |
# | 1  | 0.591 |   1    |
# | 2  | 0.478 |   0    |
# | 3  | 0.166 |   0    |
# | 4  | 0.932 |   1    |
# | 5  | 0.926 |   0    |
# | 6  | 0.007 |   0    |
# | 7  | 0.551 |   1    |
# | 8  | 0.362 |   0    |
# | 9  | 0.533 |   1    |
# | 10 | 0.368 |   0    |
# | 11 | 0.437 |   1    |
# | 12 | 0.178 |   0    |
# | 13 | 0.411 |   1    |
# | 14 | 0.545 |   1    |
# | 15 | 0.787 |   1    |
# | 16 | 0.594 |   0    |
# | 17 | 0.086 |   0    |
# | 18 | 0.951 |   1    |
# | 19 | 0.772 |   0    |
# | 20 | 0.298 |   0    |
# | 21 | 0.199 |   0    |
# | 22 | 0.157 |   0    |
# | 23 | 0.401 |   1    |
# | 24 | 0.631 |   1    |
# +----+-------+--------+
#
# H_o = Los números de la muestra son independientes
# H_a = Los números de la muestra no son independientes
#
# Nivel de aceptación: 0.95
# Rachas observadas:  15
# media 16.3333
# varianza 4.1222
#
# Valor z en N(0,1) 1.96
# Valor de Z_o -0.6567
#
# -1.959963984540054 < -0.6567091033031179 < 1.959963984540054
# H_o se acepta
